# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Homicides in California
# `openjustice.doj.ca.gov-homicide-1.1.1` Last Update: 2020-06-16T21:27:22
#
# _Homicides reported to the California DOJ by local law enforcement._
#
#
# ## Processing
#
# The value label files were manually extracted from the data dictionary PDF.
#
# Manslaughter 50 to 59
# Justifiable by Citizen ONLY 80 to 89
# Justifiable by Peace Officer ONLY 90 to 99
# ## Documentation Links
#
# * [Data documentation](https://data-openjustice.doj.ca.gov/sites/default/files/dataset/2019-07/Homicide%20Context_062419.pdf) Data documentation and data dictionary
# * [Homicide in California in 2019](https://data-openjustice.doj.ca.gov/sites/default/files/2019-07/Homicide%20In%20CA%2020190701.pdf) Report based on this dataset.
# * [Data download page](https://openjustice.doj.ca.gov/data)
# * [Open Justice Home Page](https://openjustice.doj.ca.gov/)
#
#
#
# ## Contacts
#
# ...

# %%
vl = pkg.reference('vl_source').dataframe()
vl
# Out:
#                 variable code                 label subject_heading
# 0    precipitating_event   02                 Rape         Actuals
# 1    precipitating_event   03              Robbery         Actuals
# 2    precipitating_event   05             Burglary         Actuals
# 3    precipitating_event   06              Larceny         Actuals
# 4    precipitating_event   07  Motor vehicle theft         Actuals
# ..                   ...  ...                   ...             ...
# 144       race_ethnicity    L               Laotian             NaN
# 145       race_ethnicity    S                Samoan             NaN
# 146       race_ethnicity    U              Hawaiian             NaN
# 147       race_ethnicity    V            Vietnamese             NaN
# 148       race_ethnicity    Z          Asian Indian             NaN
#
# [149 rows x 4 columns]

# %%
vl.variable.unique()
# Out:
# array(['precipitating_event', 'means_of_death', 'location',
#        'relationship', 'gender', 'race_ethnicity'], dtype=object)

# %%
precipitating_event_labels = vl[vl.variable=='precipitating_event'][['code','label','subject_heading']]\
            .rename(columns={'code': 'precipitating_event', 'label': 'precipitating_event_label' })

def cvt(vl, var_name):
    return vl[vl.variable==var_name][['code','label']]\
        .rename(columns={'code': var_name, 'label': var_name+'_label' })

means_of_death_labels = cvt(vl,'means_of_death')
location_labels = cvt(vl,'location')
gender_labels =  cvt(vl,'gender')
relationship_labels =  cvt(vl,'relationship')
race_ethnicity_labels = cvt(vl,'race_ethnicity')

# %%
race_ethnicity_labels
# Out:
#     race_ethnicity race_ethnicity_label
# 120              0              Unknown
# 121              X              Unknown
# 122              1                White
# 123              W                White
# 124              2             Hispanic
# 125              H             Hispanic
# 126              3                Black
# 127              B                Black
# 128              4      American Indian
# 129              I      American Indian
# 130              5              Chinese
# 131              C              Chinese
# 132              6             Japanese
# 133              J             Japanese
# 134              7             Filipino
# 135              F             Filipino
# 136              8                Other
# 137              O                Other
# 138              9     Pacific Islander
# 139              P     Pacific Islander
# 140              A          Other Asian
# 141              D            Cambodian
# ...
